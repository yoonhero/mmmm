# %%
from mobius_cnns.data_loader import build_mnist_loader
data_root = "/Users/ysh/Desktop/study/MobiusCNNs/data/"
train_loader = build_mnist_loader(mode="train", shifted=True, batch_size=64, data_root=data_root)
test_loader = build_mnist_loader(mode="test", shifted=True, batch_size=64, data_root=data_root)

# %%
from torchvision.transforms import ToPILImage
import matplotlib.pyplot as plt
plt.imshow(ToPILImage()(next(iter(train_loader))[0][0]))
